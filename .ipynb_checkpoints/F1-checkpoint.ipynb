# %%
# Tratamiento de datos
# ==============================================================================
import numpy as np
import pandas as pd

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
import matplotlib.font_manager
from matplotlib.ticker import MultipleLocator
from matplotlib import style
style.use('ggplot') or plt.style.use('ggplot')
import seaborn as sns
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

# %%
df_result=pd.read_csv('results.csv',encoding='utf-8',sep=',')

# %%
df_races=pd.read_csv('races.csv',encoding='utf-8',sep=',')

# %%
df_drivers=pd.read_csv('drivers.csv',encoding='utf-8',sep=',')

# %%
df_constructor=pd.read_csv('constructors.csv',encoding='utf-8',sep=',')

# %%
df_constructor
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# 2    http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3    http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4     http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ..                                                 ...
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 210        http://en.wikipedia.org/wiki/Alpine_F1_Team
#
# [211 rows x 5 columns]

# %%
df_status=pd.read_csv('status.csv',encoding='utf-8',sep=',')

# %%
df_sprint=pd.read_csv('sprint_results.csv',encoding='utf-8',sep=',')

# %%
df_races.year=df_races.year.astype(str)

# %%
df_races2022=df_races[df_races['year']=='2023']

# %%
df_result['driverName']=df_result['driverId'].map(df_drivers.set_index('driverId')['surname'])

# %%
df_races2022.tail()
# Out:
#       raceId  year  round  circuitId                      name  ...  fp3_time  \
# 1097    1116  2023     19         69  United States Grand Prix  ...        \N
# 1098    1117  2023     20         32    Mexico City Grand Prix  ...  17:30:00
# 1099    1118  2023     21         18      São Paulo Grand Prix  ...        \N
# 1100    1119  2023     22         80      Las Vegas Grand Prix  ...  04:30:00
# 1101    1120  2023     23         24      Abu Dhabi Grand Prix  ...  10:30:00
#
#       quali_date quali_time sprint_date sprint_time
# 1097  2023-10-20   21:00:00  2023-10-21    22:00:00
# 1098  2023-10-28   21:00:00          \N          \N
# 1099  2023-11-03   18:00:00  2023-11-04    18:30:00
# 1100  2023-11-18   08:00:00          \N          \N
# 1101  2023-11-25   14:00:00          \N          \N
#
# [5 rows x 18 columns]

# %%
df_result['constructorName']=df_result['constructorId'].map(df_constructor.set_index('constructorId')['name'])

# %%
df_result['statusDescription']=df_result['statusId'].map(df_status.set_index('statusId')['status'])

# %%
df_result['gpName']=df_result['raceId'].map(df_races2022.set_index('raceId')['name'])
df_result['gpDate']=df_result['raceId'].map(df_races2022.set_index('raceId')['date'])
df_result['gpYear']=df_result['raceId'].map(df_races2022.set_index('raceId')['year'])

# %%
df_result.gpName.value_counts()
# Out:
# Bahrain Grand Prix          20
# Saudi Arabian Grand Prix    20
# Australian Grand Prix       20
# Azerbaijan Grand Prix       20
# Miami Grand Prix            20
# Name: gpName, dtype: int64

# %%
df_result=df_result.dropna(axis=0)

# %%
df_result['position']=df_result['position'].replace(['\\N'],'21')
df_result.position=df_result.position.astype(int)
df_result['fastestLapTime']=df_result['fastestLapTime'].replace(['\\N'],0)

# %%
df_result[df_result['gpYear']=='2023']
# Out:
#        resultId  raceId  driverId  constructorId number  ...  constructorName  \
# 25840     25846    1098       830              9      1  ...         Red Bull
# 25841     25847    1098       815              9     11  ...         Red Bull
# 25842     25848    1098         4            117     14  ...     Aston Martin
# 25843     25849    1098       832              6     55  ...          Ferrari
# 25844     25850    1098         1            131     44  ...         Mercedes
# ...         ...     ...       ...            ...    ...  ...              ...
# 25935     25941    1102       855             51     24  ...       Alfa Romeo
# 25936     25942    1102       846              1      4  ...          McLaren
# 25937     25943    1102       856            213     21  ...       AlphaTauri
# 25938     25944    1102       857              1     81  ...          McLaren
# 25939     25945    1102       858              3      2  ...         Williams
#
#        statusDescription              gpName      gpDate  gpYear
# 25840           Finished  Bahrain Grand Prix  2023-03-05    2023
# 25841           Finished  Bahrain Grand Prix  2023-03-05    2023
# 25842           Finished  Bahrain Grand Prix  2023-03-05    2023
# 25843           Finished  Bahrain Grand Prix  2023-03-05    2023
# 25844           Finished  Bahrain Grand Prix  2023-03-05    2023
# ...                  ...                 ...         ...     ...
# 25935           Finished    Miami Grand Prix  2023-05-07    2023
# 25936           Finished    Miami Grand Prix  2023-05-07    2023
# 25937           Finished    Miami Grand Prix  2023-05-07    2023
# 25938             +1 Lap    Miami Grand Prix  2023-05-07    2023
# 25939             +1 Lap    Miami Grand Prix  2023-05-07    2023
#
# [100 rows x 24 columns]

# %%
df_MaxHam=df_result[(df_result['driverName']=='Verstappen')|(df_result['driverName']=='Leclerc')|(df_result['driverName']=='Sainz')|(df_result['driverName']=='Russell')|(df_result['driverName']=='Leclerc')|(df_result['driverName']=='Pérez')|(df_result['driverName']=='Hamilton')]

# %%
df_MaxHam2=df_result[(df_result['driverName']=='Verstappen')|(df_result['driverName']=='Pérez')]

# %%
df_Standing=df_result.groupby(by='driverName')['points'].sum('points').sort_values( ascending=True)

# %%
df_Standing=pd.DataFrame(df_Standing)

# %%
df_Standing=df_Standing.reset_index()

# %%
g=sns.catplot(x='driverName',y='points',data=df_Standing,kind='bar', height=8.27, aspect=11.7/8.27)
plt.xticks(rotation=45)
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1):.1f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

plt.show()

# %%
df_Standing.columns
# Out:
# Index(['driverName', 'points'], dtype='object')

# %%
df_result = df_result.reset_index()

# %%
df_result[df_result['raceId']>=1098]
# Out:
#     index  resultId  raceId  driverId  constructorId  ... constructorName  \
# 0   25840     25846    1098       830              9  ...        Red Bull
# 1   25841     25847    1098       815              9  ...        Red Bull
# 2   25842     25848    1098         4            117  ...    Aston Martin
# 3   25843     25849    1098       832              6  ...         Ferrari
# 4   25844     25850    1098         1            131  ...        Mercedes
# ..    ...       ...     ...       ...            ...  ...             ...
# 95  25935     25941    1102       855             51  ...      Alfa Romeo
# 96  25936     25942    1102       846              1  ...         McLaren
# 97  25937     25943    1102       856            213  ...      AlphaTauri
# 98  25938     25944    1102       857              1  ...         McLaren
# 99  25939     25945    1102       858              3  ...        Williams
#
#     statusDescription              gpName      gpDate  gpYear
# 0            Finished  Bahrain Grand Prix  2023-03-05    2023
# 1            Finished  Bahrain Grand Prix  2023-03-05    2023
# 2            Finished  Bahrain Grand Prix  2023-03-05    2023
# 3            Finished  Bahrain Grand Prix  2023-03-05    2023
# 4            Finished  Bahrain Grand Prix  2023-03-05    2023
# ..                ...                 ...         ...     ...
# 95           Finished    Miami Grand Prix  2023-05-07    2023
# 96           Finished    Miami Grand Prix  2023-05-07    2023
# 97           Finished    Miami Grand Prix  2023-05-07    2023
# 98             +1 Lap    Miami Grand Prix  2023-05-07    2023
# 99             +1 Lap    Miami Grand Prix  2023-05-07    2023
#
# [100 rows x 25 columns]

# %%
df_laptime=pd.read_csv('lap_times.csv',encoding='utf-8',sep=',')

# %%
df_laptime['driverName']=df_laptime['driverId'].map(df_drivers.set_index('driverId')['surname'])

# %%
df_laptime['GPName']=df_laptime['raceId'].map(df_races.set_index('raceId')['name'])

# %%
df_GPGB=df_laptime[(df_laptime['raceId']>=1098)]

# %%
races=df_GPGB.raceId.unique()

# %%
dfXD=df_GPGB[((df_GPGB['driverName']=='Pérez') | (df_GPGB['driverName']=='Sainz') | (df_GPGB['driverName']=='Verstappen') | (df_GPGB['driverName']=='Leclerc') | (df_GPGB['driverName']=='Hamilton') | (df_GPGB['driverName']=='Russell') )]

# %%
for x in races:
    df_GPGB=df_laptime[((df_laptime['raceId']==x) & ((df_laptime['driverName']=='Pérez') | (df_laptime['driverName']=='Sainz') | (df_laptime['driverName']=='Verstappen') | (df_laptime['driverName']=='Leclerc') | (df_laptime['driverName']=='Hamilton') | (df_laptime['driverName']=='Russell') | (df_laptime['driverName']=='Alonso') ))]
    
    g=sns.relplot(x='lap',y='position',data=df_GPGB, kind='line',hue='driverName',col='GPName',height=8.27, aspect=11.7/8.27)
    g.set(ylim=(21, 0))
    g.set(xlim=(-1, df_GPGB.lap.max()))
    for ax in g.axes.flat:
        ax.yaxis.set_major_locator(MultipleLocator(1))

    for ax in g.axes.flat:
        ax.xaxis.set_major_locator(MultipleLocator(1))    

    plt.show()

# %%
standing=pd.read_csv('driver_standings.csv',encoding='utf-8',sep=',')

# %%
standing['driverName']=standing['driverId'].map(df_drivers.set_index('driverId')['surname'])

# %%
standing=standing[(standing['raceId']==standing['raceId'].max())]

# %%
standing=standing.sort_values(by='points')

# %%
standing
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 33975              71959    1102       856     0.0        20           20
# 33973              71957    1102       858     0.0        19           19
# 33971              71955    1102       848     1.0        18           18
# 33977              71961    1102       855     2.0        15           15
# 33974              71958    1102       825     2.0        17           17
# ...                  ...     ...       ...     ...       ...          ...
# 33965              71949    1102       832    44.0         5            5
# 33966              71950    1102         1    56.0         4            4
# 33964              71948    1102         4    75.0         3            3
# 33963              71947    1102       815   105.0         2            2
# 33962              71946    1102       830   119.0         1            1
#
#        wins  driverName
# 33975     0    de Vries
# 33973     0    Sargeant
# 33971     0       Albon
# 33977     0        Zhou
# 33974     0   Magnussen
# ...     ...         ...
# 33965     0       Sainz
# 33966     0    Hamilton
# 33964     0      Alonso
# 33963     2       Pérez
# 33962     3  Verstappen
#
# [20 rows x 8 columns]

# %%
g= sns.catplot(x='driverName',y='points',data=standing, height=8.27, aspect=1.41,kind='bar',ci=None).set(title='Campeonato de pilotos')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)
g.set_xticklabels(rotation=45, horizontalalignment='right')

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1):.1f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')


plt.show()

# %%
standing=standing.sort_values(by='wins')

# %%
g= sns.catplot(x='driverName',y='wins',data=standing, height=8.27, aspect=1.41,kind='bar',ci=None).set(title='Victorias en la temporada')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)
g.set_xticklabels(rotation=45, horizontalalignment='right')

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1):.1f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')


plt.show()

# %%
standingConstructors=pd.read_csv('constructor_standings.csv',encoding='utf-8',sep=',')

# %%
standingConstructors
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12976                   28468    1102            214    14.0         6
# 12977                   28469    1102              3     1.0        10
# 12978                   28470    1102            213     2.0         9
# 12979                   28471    1102            210     8.0         7
# 12980                   28472    1102              1    14.0         5
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# 3                4     0
# 4                5     0
# ...            ...   ...
# 12976            6     0
# 12977           10     0
# 12978            9     0
# 12979            7     0
# 12980            5     0
#
# [12981 rows x 7 columns]

# %%
standingConstructors['Equipo']=standingConstructors['constructorId'].map(df_constructor.set_index('constructorId')['name'])

# %%
standingConstructors
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12976                   28468    1102            214    14.0         6
# 12977                   28469    1102              3     1.0        10
# 12978                   28470    1102            213     2.0         9
# 12979                   28471    1102            210     8.0         7
# 12980                   28472    1102              1    14.0         5
#
#       positionText  wins          Equipo
# 0                1     1         McLaren
# 1                3     0      BMW Sauber
# 2                2     0        Williams
# 3                4     0         Renault
# 4                5     0      Toro Rosso
# ...            ...   ...             ...
# 12976            6     0  Alpine F1 Team
# 12977           10     0        Williams
# 12978            9     0      AlphaTauri
# 12979            7     0    Haas F1 Team
# 12980            5     0         McLaren
#
# [12981 rows x 8 columns]

# %%
standingConstructors=standingConstructors[(standingConstructors['raceId']==standingConstructors['raceId'].max())]

# %%
standingConstructors=standingConstructors.sort_values(by='points')

# %%
standingConstructors
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 12977                   28469    1102              3     1.0        10
# 12978                   28470    1102            213     2.0         9
# 12975                   28467    1102             51     6.0         8
# 12979                   28471    1102            210     8.0         7
# 12976                   28468    1102            214    14.0         6
# 12980                   28472    1102              1    14.0         5
# 12973                   28465    1102              6    78.0         4
# 12974                   28466    1102            131    96.0         3
# 12972                   28464    1102            117   102.0         2
# 12971                   28463    1102              9   224.0         1
#
#       positionText  wins          Equipo
# 12977           10     0        Williams
# 12978            9     0      AlphaTauri
# 12975            8     0      Alfa Romeo
# 12979            7     0    Haas F1 Team
# 12976            6     0  Alpine F1 Team
# 12980            5     0         McLaren
# 12973            4     0         Ferrari
# 12974            3     0        Mercedes
# 12972            2     0    Aston Martin
# 12971            1     5        Red Bull

# %%
g= sns.catplot(x='Equipo',y='points',data=standingConstructors, height=8.27, aspect=1.41,kind='bar',ci=None).set(title='Campeonato de Constructores')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)
g.set_xticklabels(rotation=45, horizontalalignment='right')

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1):.1f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')


plt.show()

# %%
standingConstructors=standingConstructors.sort_values(by='wins')

# %%
g= sns.catplot(x='Equipo',y='wins',data=standingConstructors, height=8.27, aspect=1.41,kind='bar',ci=None).set(title='Campeonato de pilotos')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)
g.set_xticklabels(rotation=45, horizontalalignment='right')

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1):.1f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')


plt.show()
